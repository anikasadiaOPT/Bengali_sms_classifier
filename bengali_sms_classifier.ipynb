# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data1_df = pd.read_csv('sms_dataset.csv')
data2_df = pd.read_csv('data.csv')
data3_df = pd.read_csv('promo_sms_dataset.csv')
data4_df = pd.read_csv('bengali_normal_sms_dataset.csv')

# %%
data3_df.tail(20)
# Out:
#       label                                               text
# 1980  promo  বই কেনার সাথে ফ্রি বুকমার্ক বড় সেভিংস এবং ফ্রি...
# 1981  promo  আজই স্টোরে আসুন এবং অফার উপভোগ করুন আমাদের নতু...
# 1982  promo  নতুন হেলথ সাপ্লিমেন্ট কালেকশন জুতো কিনুন নতুন ...
# 1983  promo  আজই অনলাইনে অর্ডার করুন ফ্ল্যাশ সেল শুরু! আজই ...
# 1984  promo  নতুন খাবারের combo pack উপলব্ধ ফ্রি ডেলিভারি এ...
# 1985  promo  নতুন খাবারের combo pack উপলব্ধ আজই হোম অ্যাপ্ল...
# 1986  promo  সীমিত সময়ের জন্য ডিসকাউন্ট স্মার্টওয়াচে বিশে...
# 1987  promo  হোম অ্যাপ্লায়েন্সে বড় ছাড় পানি সংরক্ষণ ও বর...
# 1988  promo  মেগা সেল চলছে এই সপ্তাহে এয়ার কন্ডিশনারে ডিসক...
# 1989  promo  জুতো কিনুন নতুন কালেকশনে। ডিসকাউন্ট চলছে। ফ্রী...
# 1990  promo  ওয়াশিং মেশিনে ফ্রী ডেলিভারি বড় সেভিংস এবং ফ্র...
# 1991  promo  ৩০ জুন ২০২৫ এর মধ্যে আপনার ভূমি উন্নয়ন কর অনলা...
# 1992  promo  বিশেষ উৎসব অফার শুরু হয়েছে বিশেষ উৎসব অফার! আ...
# 1993  promo  আজই অনলাইনে অর্ডার করুন বিশেষ উৎসব অফার শুরু হ...
# ...

# %%
data1_df['label'].unique()
# Out:
# array(['spam'], dtype=object)

# %%
data1_df[data1_df['label'] == 'spam']
# Out:
#      label                                               text
# 0     spam  পাসওয়ার্ড পরিবর্তন করুন এখনই বিনিয়োগের সুযোগ...
# 1     spam  ব্যক্তিগত লোনের অফার ১০ দিনে ওজন কমান অনলাইন ই...
# 2     spam  চ্যাট করতে এখনই লগইন করুন বিনামূল্যে গিফট ভাউচ...
# 3     spam  নিশ্চিত মুনাফার অফার বিনিয়োগের সুযোগ সীমিত ফ্...
# 4     spam  আজকের ভাগ্যবান আপনি সহজ কাজ করে টাকা আয় করুন ...
# ...    ...                                                ...
# 1995  spam  মেগা কন্টেস্টে অংশ নিন ডায়েট চার্ট ফ্রি পাচ্ছ...
# 1996  spam  আপনার নাম লটারিতে উঠেছে আজকের বিজয়ী তালিকায় ...
# 1997  spam  হাড়ের ব্যথা দূর করুন দ্রুত আপনার নাম নির্বাচি...
# 1998  spam  আপনার একাউন্টে অননুমোদিত লগইন সেক্স চ্যাট অ্যা...
# 1999  spam  মেয়েদের সাথে চ্যাট করুন তাত্ক্ষণিক একশন নিন দ...
#
# [2000 rows x 2 columns]

# %%
data2_df['label'] = data2_df['label'].replace({'smish':'spam', 'ham':'normal'})
#data4_df['label'] = data4_df['label'].replace({'ham':'normal'})

# %%
data4_df[data4_df['label'] == 'normal']
# Out:
#        label                                               text
# 0     normal  তোমার জন্য শুভকামনা আগামী সপ্তাহে ঘুরতে যাবো আ...
# 1     normal   আবার কথা হবে শরীরের যত্ন নাও আজ নতুন জামা কিনলাম
# 2     normal  কেমন আছো চল গান গাই তুমি কি কিছু কিনেছো রাতের ...
# 3     normal  তাড়াতাড়ি ফিরো চল হাসপাতাল যাই লাইব্রেরিতে যা...
# 4     normal  আজ ডিসকাউন্ট চলছে কোন গান শুনছো কেমন আছো তোমার...
# ...      ...                                                ...
# 1995  normal  আশা করি শিগগির দেখা হবে তুমি কেমন আছো বাজারে ভ...
# 1996  normal  আমার মা আজ বাজারে গেছে শুভ সকাল চল পিজ্জা খাই ...
# 1997  normal         বাসে যেতে হবে বাসে যেতে হবে আজকে বাইরে যাই
# 1998  normal  তুমি কি কিছু কিনেছো শুভ দিন বাজারে ভিড় ছিলো স...
# 1999  normal  গ্রামে বেড়াতে যাবো বাজারে ভিড় ছিলো তোমার খবর কি
#
# [2000 rows x 2 columns]

# %%
data3_df[data3_df['label'] == 'spam']
# Out:
# Empty DataFrame
# Columns: [label, text]
# Index: []

# %%
data2_df[data2_df['label'] == 'promo']
# Out:
#       label                                               text
# 2     promo  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...
# 3     promo  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...
# 5     promo  ৪০৳ ক্যাশব্যাক! ৪৬জিবি @৪৫৮৳, ৩০দিন, নিয়ে নাও ...
# 7     promo  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
# 8     promo    সব ডিভিডিতে ১০% ছাড়। অফারটি সীমিত সময়ের জন্য।
# ...     ...                                                ...
# 2752  promo  ১৫০৳ ক্যাশব্যাকে নাও ডাটা মিক্সার ৮০জিবি@৳৬৯৯,...
# 2755  promo  ৫জিবি+১৫০মিনিট ১৩০টাকা (৩০দিন),ডায়াল *১২১*৫২০৫...
# 2757  promo  বড় ডিসকাউন্ট! শীতের পোশাকে ৩০% ছাড়। আজই ভিজি...
# 2761  promo  আড্ডা+ইন্টারনেটিংয়ে নতুন ডিল ১০জিবি+২৫০মি@২৫৮...
# 2766  promo  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
#
# [924 rows x 2 columns]

# %%
data2_df[data2_df['label'] == 'promo']
# Out:
#       label                                               text
# 2     promo  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...
# 3     promo  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...
# 5     promo  ৪০৳ ক্যাশব্যাক! ৪৬জিবি @৪৫৮৳, ৩০দিন, নিয়ে নাও ...
# 7     promo  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
# 8     promo    সব ডিভিডিতে ১০% ছাড়। অফারটি সীমিত সময়ের জন্য।
# ...     ...                                                ...
# 2752  promo  ১৫০৳ ক্যাশব্যাকে নাও ডাটা মিক্সার ৮০জিবি@৳৬৯৯,...
# 2755  promo  ৫জিবি+১৫০মিনিট ১৩০টাকা (৩০দিন),ডায়াল *১২১*৫২০৫...
# 2757  promo  বড় ডিসকাউন্ট! শীতের পোশাকে ৩০% ছাড়। আজই ভিজি...
# 2761  promo  আড্ডা+ইন্টারনেটিংয়ে নতুন ডিল ১০জিবি+২৫০মি@২৫৮...
# 2766  promo  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
#
# [924 rows x 2 columns]

# %%
data2_df['label'].value_counts()
# Out:
# label
# spam      924
# promo     924
# normal    924
# Name: count, dtype: int64

# %%
data3_df.head(30)
# Out:
#     label                                               text
# 0   promo  ফ্ল্যাশ সেল শুরু! আজই অর্ডার করুন নতুন অ্যালবা...
# 1   promo  বড় সেভিংস এবং ফ্রি গিফট কার্ড আপনার জন্য নতুন ...
# 2   promo  স্ট্রিমিং সাবস্ক্রিপশন ছাড়ে উপলব্ধ বিশেষ উৎসব...
# 3   promo  নতুন অ্যালবাম এবং মিউজিক কালেকশন শিশু শিক্ষার ...
# 4   promo  ল্যাপটপে সীমিত সময়ের ডিসকাউন্ট শিক্ষামূলক বইয...
# 5   promo  জুতো কিনুন নতুন কালেকশনে। ডিসকাউন্ট চলছে। ফ্রী...
# 6   promo  ৩০ জুন ২০২৫ এর মধ্যে আপনার ভূমি উন্নয়ন কর অনলা...
# 7   promo  আজই অডিও প্রোডাক্ট কিনুন শিক্ষামূলক বইয়ের নতু...
# 8   promo  বিশেষ উৎসব অফার শুরু হয়েছে নতুন রেস্টুরেন্ট ম...
# 9   promo  আজই অনলাইনে নতুন গ্যাজেট দেখুন নতুন ক্যামেরা ক...
# 10  promo  নতুন মোবাইল ফোনে বিশেষ অফার নতুন রেস্টুরেন্ট ম...
# 11  promo  ইলেকট্রনিক্সে বছরের বড় সেল সীমিত সময়ের জন্য ...
# 12  promo  বেস্টসেলার বই এখন অনলাইনে বছরের নতুন প্রকাশনা ...
# 13  promo  বছরের নতুন প্রকাশনা উপলব্ধ বড় সেভিংস এবং ফ্রি ...
# ...

# %%
data1_df.head(50)
# Out:
#    label                                               text
# 0   spam  পাসওয়ার্ড পরিবর্তন করুন এখনই বিনিয়োগের সুযোগ...
# 1   spam  ব্যক্তিগত লোনের অফার ১০ দিনে ওজন কমান অনলাইন ই...
# 2   spam  চ্যাট করতে এখনই লগইন করুন বিনামূল্যে গিফট ভাউচ...
# 3   spam  নিশ্চিত মুনাফার অফার বিনিয়োগের সুযোগ সীমিত ফ্...
# 4   spam  আজকের ভাগ্যবান আপনি সহজ কাজ করে টাকা আয় করুন ...
# 5   spam  অনলাইন ইনকাম করুন অ্যাকাউন্ট ব্লক হয়ে গেছে নত...
# 6   spam  অবিলম্বে রেজিস্টার করুন ডেটা এন্ট্রি কাজের অফা...
# 7   spam  উচ্চ রিটার্নের বিনিয়োগের সুযোগ ফ্রি অ্যাডাল্ট...
# 8   spam  মেয়েদের সাথে চ্যাট করুন তাড়াতাড়ি ওজন কমানোর...
# 9   spam  ভিডিও কলের জন্য অ্যাপ ডাউনলোড করুন গিফট ভাউচার...
# 10  spam  শেয়ার মার্কেট হট অফার আপনার নাম নির্বাচিত হয়...
# 11  spam  হাড়ের ব্যথা দূর করুন দ্রুত শেয়ার মার্কেট হট ...
# 12  spam  বন্ধুত্ব করতে রেজিস্টার করুন বিউটি টিপস পেতে ক...
# 13  spam  আপনি নির্বাচিত হয়েছেন সুপার প্রাইজ জেতার সুযো...
# 14  spam  ফ্রি কলের সুযোগ আপনি নতুন সাবস্ক্রিপশনের জন্য ...
# ...

# %%
df = pd.concat([data2_df,data1_df,data4_df,data3_df], ignore_index = True)

# %%
dataset = df.to_csv('Bengali_sms_dataset.csv', index = False)

# %%
df.head(50)
# Out:
#      label                                               text
# 0     spam  সোনালী ব্যাংক অ্যাকাউন্টে সমস্যা হয়েছে। কল কর...
# 1     spam  ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...
# 2    promo  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...
# 3    promo  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...
# 4     spam  আপনার ব্যাংক কার্ডটি অবিলম্বে আপডেট করুন। এখান...
# 5    promo  ৪০৳ ক্যাশব্যাক! ৪৬জিবি @৪৫৮৳, ৩০দিন, নিয়ে নাও ...
# 6     spam  আজই ক্যাসিনোতে বাজি ধরুন এবং একটি বিলাসবহুল ট্...
# 7    promo  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
# 8    promo    সব ডিভিডিতে ১০% ছাড়। অফারটি সীমিত সময়ের জন্য।
# 9    promo  হটশট ক্যাশব্যাক ৳২০! হটস্পট ডিলে ২২জিবি@৳১৭৭, ...
# 10   promo  ৳৮০ ক্যাশব্যাকে বেশি বেশি ডাটা ৩০জিবি@৳৩১৯, ৩০...
# 11    spam  আপনার অ্যাকাউন্টটি সাময়িকভাবে নিষ্ক্রিয় করা ...
# 12   promo  <#> আপনার মাইজিপি পিন (code) হচ্ছে: 4283. ভেরি...
# 13   promo  নতুন গ্রাহকদের জন্য স্পেশাল অফার! আমাদের সার্ভ...
# ...

# %%
df.shape
# Out:
# (8772, 2)

# %%
df[df['label'] == 2]
# Out:
# Empty DataFrame
# Columns: [label, text]
# Index: []

# %%
df['label'] == 'promo'
# Out:
# 0       False
# 1       False
# 2        True
# 3        True
# 4       False
#         ...
# 8767     True
# 8768     True
# 8769     True
# 8770     True
# 8771     True
# Name: label, Length: 8772, dtype: bool

# %%
df['label'].value_counts()
# Out:
# label
# spam      2924
# promo     2924
# normal    2924
# Name: count, dtype: int64

# %%
df[df['label'] == 'normal']
# Out:
#        label                                               text
# 16    normal                                       শুভ জন্মদিন!
# 17    normal  তোমার আগে কোনো বই পড়েছি? হ্যাঁ, অনেক বই পড়েছি।...
# 22    normal                           কেমন আছে তোমাদের পরিবার?
# 23    normal                            তোমাদের দিন কেমন কাটছে?
# 25    normal                                  বন্ধুরা কেমন আছে?
# ...      ...                                                ...
# 6767  normal  আশা করি শিগগির দেখা হবে তুমি কেমন আছো বাজারে ভ...
# 6768  normal  আমার মা আজ বাজারে গেছে শুভ সকাল চল পিজ্জা খাই ...
# 6769  normal         বাসে যেতে হবে বাসে যেতে হবে আজকে বাইরে যাই
# 6770  normal  তুমি কি কিছু কিনেছো শুভ দিন বাজারে ভিড় ছিলো স...
# 6771  normal  গ্রামে বেড়াতে যাবো বাজারে ভিড় ছিলো তোমার খবর কি
#
# [2924 rows x 2 columns]

# %%
df.head(50)
# Out:
#      label                                               text
# 0     spam  সোনালী ব্যাংক অ্যাকাউন্টে সমস্যা হয়েছে। কল কর...
# 1     spam  ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...
# 2    promo  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...
# 3    promo  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...
# 4     spam  আপনার ব্যাংক কার্ডটি অবিলম্বে আপডেট করুন। এখান...
# 5    promo  ৪০৳ ক্যাশব্যাক! ৪৬জিবি @৪৫৮৳, ৩০দিন, নিয়ে নাও ...
# 6     spam  আজই ক্যাসিনোতে বাজি ধরুন এবং একটি বিলাসবহুল ট্...
# 7    promo  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
# 8    promo    সব ডিভিডিতে ১০% ছাড়। অফারটি সীমিত সময়ের জন্য।
# 9    promo  হটশট ক্যাশব্যাক ৳২০! হটস্পট ডিলে ২২জিবি@৳১৭৭, ...
# 10   promo  ৳৮০ ক্যাশব্যাকে বেশি বেশি ডাটা ৩০জিবি@৳৩১৯, ৩০...
# 11    spam  আপনার অ্যাকাউন্টটি সাময়িকভাবে নিষ্ক্রিয় করা ...
# 12   promo  <#> আপনার মাইজিপি পিন (code) হচ্ছে: 4283. ভেরি...
# 13   promo  নতুন গ্রাহকদের জন্য স্পেশাল অফার! আমাদের সার্ভ...
# ...

# %%
df.isnull().sum()
# Out:
# label    0
# text     0
# dtype: int64

# %%
df.drop_duplicates(keep = 'first', inplace = True)

# %%
df.shape
# Out:
# (7209, 2)

# %%
df['label'].value_counts()
# Out:
# label
# spam      2522
# normal    2439
# promo     2248
# Name: count, dtype: int64

# %%
X = df['text']
y = df.iloc[:, 0:1].values

# %%
df['label'] = df['label'].replace('smish', 'spam')

# %%
df.shape
# Out:
# (7209, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7209 entries, 0 to 8771
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   7209 non-null   object
#  1   text    7209 non-null   object
# dtypes: object(2)
# memory usage: 169.0+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['label'] = le.fit_transform(df['label'])

# %%
df[df['label'] == 1]
# Out:
#       label                                               text
# 2         1  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...
# 3         1  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...
# 5         1  ৪০৳ ক্যাশব্যাক! ৪৬জিবি @৪৫৮৳, ৩০দিন, নিয়ে নাও ...
# 7         1  নতুন কাস্টমারদের জন্য বিশেষ ডিসকাউন্ট। আজই রেজ...
# 8         1    সব ডিভিডিতে ১০% ছাড়। অফারটি সীমিত সময়ের জন্য।
# ...     ...                                                ...
# 8767      1  পরিবেশ ও জনস্বাস্থ্য সুরক্ষায় কুরবানির বর্জ্য ...
# 8768      1  নতুন বইয়ের কালেকশন এসেছে সদস্যদের জন্য এক্সট্...
# 8769      1  নতুন রেফ্রিজারেটর কালেকশন ফ্ল্যাশ সেল শুরু! আজ...
# 8770      1  বছরের সবচেয়ে বড় সেল চলছে বছরের সবচেয়ে বড় ফ...
# 8771      1  নতুন সিনেমার টিকিটে বিশেষ অফার নতুন বই ও মিউজি...
#
# [2248 rows x 2 columns]

# %%
df['label'].value_counts()
# Out:
# label
# 2    2522
# 0    2439
# 1    2248
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (7209, 2)

# %%
y = df['label'].values
y
# Out:
# array([2, 2, 1, ..., 1, 1, 1], shape=(7209,))

# %%
X
# Out:
# 0       সোনালী ব্যাংক অ্যাকাউন্টে সমস্যা হয়েছে। কল কর...
# 1       ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...
# 2       স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...
# 3       ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...
# 4       আপনার ব্যাংক কার্ডটি অবিলম্বে আপডেট করুন। এখান...
#                               ...
# 8767    পরিবেশ ও জনস্বাস্থ্য সুরক্ষায় কুরবানির বর্জ্য ...
# 8768    নতুন বইয়ের কালেকশন এসেছে সদস্যদের জন্য এক্সট্...
# 8769    নতুন রেফ্রিজারেটর কালেকশন ফ্ল্যাশ সেল শুরু! আজ...
# 8770    বছরের সবচেয়ে বড় সেল চলছে বছরের সবচেয়ে বড় ফ...
# 8771    নতুন সিনেমার টিকিটে বিশেষ অফার নতুন বই ও মিউজি...
# Name: text, Length: 7209, dtype: object

# %%
df['label'] == 0
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8767    False
# 8768    False
# 8769    False
# 8770    False
# 8771    False
# Name: label, Length: 7209, dtype: bool

# %% [markdown]
# # EDA

# %%
plt.pie(df['label'].value_counts(), labels = ['spam', 'normal', 'promo'], autopct = '%0.2f')
plt.show()

# %%
df['num_char'] = df['text'].apply(len)

# %%
df
# Out:
#       label                                               text  num_char
# 0         2  সোনালী ব্যাংক অ্যাকাউন্টে সমস্যা হয়েছে। কল কর...        64
# 1         2  ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...        71
# 2         1  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...        65
# 3         1  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...        58
# 4         2  আপনার ব্যাংক কার্ডটি অবিলম্বে আপডেট করুন। এখান...        89
# ...     ...                                                ...       ...
# 8767      1  পরিবেশ ও জনস্বাস্থ্য সুরক্ষায় কুরবানির বর্জ্য ...       257
# 8768      1  নতুন বইয়ের কালেকশন এসেছে সদস্যদের জন্য এক্সট্...       118
# 8769      1  নতুন রেফ্রিজারেটর কালেকশন ফ্ল্যাশ সেল শুরু! আজ...        92
# 8770      1  বছরের সবচেয়ে বড় সেল চলছে বছরের সবচেয়ে বড় ফ...        90
# 8771      1  নতুন সিনেমার টিকিটে বিশেষ অফার নতুন বই ও মিউজি...       137
#
# [7209 rows x 3 columns]

# %%
import nltk
import string
from nltk.corpus import stopwords

# %%
df['num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))

# %%
df
# Out:
#       label                                               text  num_char  \
# 0         2  সোনালী ব্যাংক অ্যাকাউন্টে সমস্যা হয়েছে। কল কর...        64
# 1         2  ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...        71
# 2         1  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...        65
# 3         1  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...        58
# 4         2  আপনার ব্যাংক কার্ডটি অবিলম্বে আপডেট করুন। এখান...        89
# ...     ...                                                ...       ...
# 8767      1  পরিবেশ ও জনস্বাস্থ্য সুরক্ষায় কুরবানির বর্জ্য ...       257
# 8768      1  নতুন বইয়ের কালেকশন এসেছে সদস্যদের জন্য এক্সট্...       118
# 8769      1  নতুন রেফ্রিজারেটর কালেকশন ফ্ল্যাশ সেল শুরু! আজ...        92
# 8770      1  বছরের সবচেয়ে বড় সেল চলছে বছরের সবচেয়ে বড় ফ...        90
# 8771      1  নতুন সিনেমার টিকিটে বিশেষ অফার নতুন বই ও মিউজি...       137
#
#       num_words
# 0             9
# 1            12
# 2            10
# 3            12
# ...

# %%
df['num_sentence'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df
# Out:
#       label                                               text  num_char  \
# 0         2  সোনালী ব্যাংক অ্যাকাউন্টে সমস্যা হয়েছে। কল কর...        64
# 1         2  ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...        71
# 2         1  স্পেশাল ডিল শেষ দিন,৩০জিবি @৩০০৳,৩০দিন! আজই না...        65
# 3         1  ফার্নিচারে মেগা সেল! সব পণ্যে ১৫-৩০% ছাড়। আজই...        58
# 4         2  আপনার ব্যাংক কার্ডটি অবিলম্বে আপডেট করুন। এখান...        89
# ...     ...                                                ...       ...
# 8767      1  পরিবেশ ও জনস্বাস্থ্য সুরক্ষায় কুরবানির বর্জ্য ...       257
# 8768      1  নতুন বইয়ের কালেকশন এসেছে সদস্যদের জন্য এক্সট্...       118
# 8769      1  নতুন রেফ্রিজারেটর কালেকশন ফ্ল্যাশ সেল শুরু! আজ...        92
# 8770      1  বছরের সবচেয়ে বড় সেল চলছে বছরের সবচেয়ে বড় ফ...        90
# 8771      1  নতুন সিনেমার টিকিটে বিশেষ অফার নতুন বই ও মিউজি...       137
#
#       num_words  num_sentence
# 0             9             1
# ...

# %%
df[df['label'] == 0].describe()
# Out:
#         label     num_char    num_words  num_sentence
# count  2439.0  2439.000000  2439.000000   2439.000000
# mean      0.0    64.535875    12.129151      1.009020
# std       0.0    25.869939     4.680625      0.098807
# min       0.0     4.000000     1.000000      1.000000
# 25%       0.0    48.000000     9.000000      1.000000
# 50%       0.0    64.000000    12.000000      1.000000
# 75%       0.0    81.000000    15.000000      1.000000
# max       0.0   243.000000    46.000000      3.000000

# %%
sns.histplot(df[df['label'] == 2]['num_char'], color = 'red')
sns.histplot(df[df['label'] == 0]['num_char'])
# Out:
# <Axes: xlabel='num_char', ylabel='Count'>

# %%
sns.histplot(df[df['label'] == 2]['num_char'], color = 'red')
sns.histplot(df[df['label'] == 1]['num_char'], color = 'yellow')
# Out:
# <Axes: xlabel='num_char', ylabel='Count'>

# %%
sns.histplot(df[df['label'] == 2]['num_words'], color = 'red')
sns.histplot(df[df['label'] == 1]['num_words'], color = 'yellow')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.histplot(df[df['label'] == 2]['num_words'], color = 'red')
sns.histplot(df[df['label'] == 0]['num_words'])
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.histplot(df[df['label'] == 2]['num_words'], color = 'red')
sns.histplot(df[df['label'] == 1]['num_words'], color = 'yellow')
# Out:
# <Axes: xlabel='num_words', ylabel='Count'>

# %%
sns.pairplot(df, hue = 'num_char')

# %%
sns.heatmap(df.drop('text', axis = 1).corr(), annot = True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#              label     num_char    num_words  num_sentence
# count  7209.000000  7209.000000  7209.000000   7209.000000
# mean      1.011513   102.485782    17.128173      1.131502
# std       0.829536    52.294730     8.296142      0.383362
# min       0.000000     4.000000     1.000000      1.000000
# 25%       0.000000    69.000000    12.000000      1.000000
# 50%       1.000000    92.000000    16.000000      1.000000
# 75%       2.000000   124.000000    20.000000      1.000000
# max       2.000000   650.000000   123.000000      7.000000

# %%
stopwords.words('bengali')
# Out:
# ['অতএব',
#  'অথচ',
#  'অথবা',
#  'অনুযায়ী',
#  'অনেক',
#  'অনেকে',
#  'অনেকেই',
#  'অন্তত',
#  'অন্য',
#  'অবধি',
#  'অবশ্য',
#  'অর্থাত',
#  'আই',
#  'আগামী',
#  'আগে',
#  'আগেই',
#  'আছে',
#  'আজ',
#  'আদ্যভাগে',
#  'আপনার',
#  'আপনি',
#  'আবার',
#  'আমরা',
#  'আমাকে',
#  'আমাদের',
#  'আমার',
#  'আমি',
#  'আর',
#  'আরও',
#  'ই',
#  'ইত্যাদি',
#  'ইহা',
#  'উচিত',
#  'উত্তর',
#  'উনি',
#  'উপর',
#  'উপরে',
#  'এ',
#  'এঁদের',
#  'এঁরা',
#  'এই',
#  'একই',
#  'একটি',
#  'একবার',
#  'একে',
#  'এক্',
#  'এখন',
#  'এখনও',
#  'এখানে',
#  'এখানেই',
#  'এটা',
#  'এটাই',
#  'এটি',
#  'এত',
#  'এতটাই',
#  'এতে',
#  'এদের',
#  'এব',
#  'এবং',
#  'এবার',
#  'এমন',
#  'এমনকী',
#  'এমনি',
#  'এর',
#  'এরা',
#  'এল',
#  'এস',
#  'এসে',
#  'ঐ',
#  'ও',
#  'ওঁদের',
#  'ওঁর',
#  'ওঁরা',
#  'ওই',
#  'ওকে',
#  'ওখানে',
#  'ওদের',
#  'ওর',
#  'ওরা',
#  'কখনও',
#  'কত',
#  'কবে',
#  'কমনে',
#  'কয়েক',
#  'কয়েকটি',
#  'করছে',
#  'করছেন',
#  'করতে',
#  'করবে',
#  'করবেন',
#  'করলে',
#  'করলেন',
# ...

# %%
bengali_punctuation = "[{(%।॥,@&*?!-…‘’“”<#>:;)}]\n"
print(bengali_punctuation)
# Out:
# [{(%।॥,@&*?!-…‘’“”<#>:;)}]

# %%
#!pip install indic-nlp-library

# %%
from indicnlp.normalize.indic_normalize import IndicNormalizerFactory
from indicnlp.tokenize import indic_tokenize  

def bengali_stem(word):
    suffixes = ["গুলো", "গুলি", "দের", "তে", "কে", "রা", "টি", "ে"]
    for suf in suffixes:
        if word.endswith(suf):
            return word[:-len(suf)]
    return word

def processed_text(text):
    tokens = list(indic_tokenize.trivial_tokenize(text, 'bn'))
    cleaned_tokens = [
        bengali_stem(token) for token in tokens
        if token not in bengali_punctuation and token not in set(stopwords.words('bengali'))
    ]
    return ' '.join(cleaned_tokens) if cleaned_tokens else text

df['transformed_text'] = df['text'].apply(processed_text)

# %%
df['label'] == 2
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 8767    False
# 8768    False
# 8769    False
# 8770    False
# 8771    False
# Name: label, Length: 7209, dtype: bool

# %%
df['transformed_text'].head()
# Out:
# 0    সোনালী ব্যাংক অ্যাকাউন্ট সমস্যা কল করুন + 8801...
# 1    ক্রিপ্টো বিনিয়োগ লাভবান আজই করুন http / / bit...
# 2    স্পেশাল ডিল শেষ ৩০জিবি ৩০০৳ ৩০দিন আজই নাও cutt...
# 3    ফার্নিচার মেগা সেল পণ্য ১৫ ৩০ ছাড় আজই ভিজিট করুন
# 4    ব্যাংক কার্ড অবিলম্ব আপডেট করুন ক্লিক করুন ver...
# Name: transformed_text, dtype: object

# %%
df.shape
# Out:
# (7209, 6)

# %%
from wordcloud import WordCloud

spam_tokens = df[df['label'] == 2]['transformed_text'].sum()
spam_text = ' '.join(spam_tokens)
wc = WordCloud(width = 600, height = 800, font_path = "C:/Users/HP/Noto_Sans_Bengali/static/NotoSansBengali_Condensed-Regular.ttf", background_color = 'white')
spam_wc = wc.generate(spam_text)
plt.figure(figsize = (12,8))
plt.axis('off')
plt.imshow(spam_wc,interpolation='bilinear')
plt.show()

# %%
from wordcloud import WordCloud

promo_tokens = df[df['label'] == 1]['transformed_text'].sum()
promo_text = ' '.join(promo_tokens)
wc = WordCloud(width = 600, height = 800, font_path = "C:/Users/HP/Noto_Sans_Bengali/static/NotoSansBengali_Condensed-Regular.ttf", background_color = 'white')
promo_wc = wc.generate(promo_text)
plt.figure(figsize = (12,8))
plt.axis('off')
plt.imshow(promo_wc,interpolation='bilinear')
plt.show()

# %%
from wordcloud import WordCloud

normal_tokens = df[df['label'] == 1]['transformed_text'].sum()
normal_text = ' '.join(normal_tokens)
wc = WordCloud(width = 600, height = 800, font_path = "C:/Users/HP/Noto_Sans_Bengali/static/NotoSansBengali-Regular.ttf", background_color = 'white')
normal_wc = wc.generate(normal_text)
plt.figure(figsize = (12,8))
plt.axis('off')
plt.imshow(normal_wc,interpolation='bilinear')
plt.show()

# %%
spam_corpus = []
for item in df[df['label'] == 2]['transformed_text'].tolist():
    for word in item:
        spam_corpus.append(word)

# %%
len(spam_corpus)
# Out:
# 218275

# %%
promo_corpus = []
for item in df[df['label'] == 1]['transformed_text'].tolist():
    for word in item:
        promo_corpus.append(word)

# %%
len(promo_corpus)
# Out:
# 257493

# %%
normal_corpus = []
for item in df[df['label'] == 0]['transformed_text']:
    for word in item:
        normal_corpus.append(word)

# %%
len(normal_corpus)
# Out:
# 115522

# %%
df['transformed_text'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 7209 entries, 0 to 8771
# Series name: transformed_text
# Non-Null Count  Dtype
# --------------  -----
# 7209 non-null   object
# dtypes: object(1)
# memory usage: 112.6+ KB

# %% [markdown]
# # Model Building

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
cv = CountVectorizer()
tfidf2 = TfidfVectorizer(max_features = 3500)
tfidf1 = TfidfVectorizer()
X = tfidf1.fit_transform(df['transformed_text']).toarray()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state = 0)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, ComplementNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score
gnb_classifier = GaussianNB()
mnb_classifier = MultinomialNB()
cnb_classifier = ComplementNB()

# %%
gnb_classifier.fit(X_train, y_train)
mnb_classifier.fit(X_train, y_train)
cnb_classifier.fit(X_train, y_train)
# Out:
# ComplementNB()

# %%
y_pred1 = gnb_classifier.predict(X_test)
print(confusion_matrix(y_test, y_pred1))
print(accuracy_score(y_test, y_pred1))
print(precision_score(y_test, y_pred1, average = 'weighted'))
# Out:
# [[478   3   5]
#  [  9 451   4]
#  [ 16  18 458]]
# 0.9618585298196949
# 0.9623571871745363

# %%
y_pred2 = mnb_classifier.predict(X_test)
print(confusion_matrix(y_test, y_pred2))
print(accuracy_score(y_test, y_pred2))
print(precision_score(y_test, y_pred2, average = 'weighted'))
# Out:
# [[435  18  33]
#  [  4 451   9]
#  [  8   2 482]]
# 0.9486823855755895
# 0.9499411550246087

# %%
y_pred3 = cnb_classifier.predict(X_test)
print(confusion_matrix(y_test, y_pred3))
print(accuracy_score(y_test, y_pred3))
print(precision_score(y_test, y_pred3, average = 'weighted'))
# Out:
# [[450  21  15]
#  [  3 453   8]
#  [  8   5 479]]
# 0.9583911234396671
# 0.9588598018645517

# %%
np.unique(y_test, return_counts=True)
# Out:
# (array([0, 1, 2]), array([486, 464, 492]))

# %%
print(y_test.shape)
print(y_pred3.shape)
# Out:
# (1442,)
# (1442,)

# %%
X_test.shape
# Out:
# (1442, 1873)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %%
svc = SVC(kernel = 'sigmoid', gamma = 1.0)
knc = KNeighborsClassifier()
gnb = GaussianNB()
dtc = DecisionTreeClassifier(max_depth = 5)
lrc = LogisticRegression(random_state = 2)
rfc = RandomForestClassifier(n_estimators = 50, random_state = 2)
abc = AdaBoostClassifier(n_estimators = 50, random_state = 2)
bc = BaggingClassifier(n_estimators = 50, random_state = 2)
etc = ExtraTreesClassifier(n_estimators = 50, random_state = 2)
gbdt = GradientBoostingClassifier(n_estimators = 50, random_state = 2)
xgb = XGBClassifier(n_estimators = 50, random_state = 2)

stack_model = StackingClassifier(
    estimators = [
        ('ET' , etc),
        ('BC' , bc),
        ('RF', rfc),
    ],
    final_estimator = ExtraTreesClassifier(),
    cv = 5
)
voting_model = VotingClassifier(
    estimators = [
        ('NB' , gnb),
        ('SVC' , svc),
        ('ET', etc)
    ], voting = 'hard'
)

# %%
clfs = {
    'SVC' : svc,
    'KNC' : knc,
    'NB' : gnb,
    'DT' : dtc,
    'LR' : lrc,
    'RF' : rfc,
    'AB' : abc,
    'BC' : bc,
    'ET' : etc,
    'GDB' : gbdt,
    'XGB' : xgb,
    'STACK' : stack_model,
    'Voting' : voting_model
}

# %%
def train_classifier(clf, X_train, X_test, y_train, y_test):
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, average = 'weighted')
    return accuracy, precision

# %%
accuracy_scores = []
precision_scores = []

for name, clf in clfs.items():
    current_accuracy, current_precision = train_classifier(clf, X_train, X_test, y_train, y_test)
    print("Name", name)
    print("Accuracy" , current_accuracy)
    print("Precision", current_precision)

    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# Name SVC
# Accuracy 0.9764216366158114
# Precision 0.9766014857338086
# Name KNC
# Accuracy 0.9188626907073509
# Precision 0.9304980444099438
# Name NB
# Accuracy 0.9618585298196949
# Precision 0.9623571871745363
# Name DT
# Accuracy 0.855755894590846
# Precision 0.8636126797980495
# Name LR
# Accuracy 0.9687933425797504
# Precision 0.9692266266809684
# Name RF
# Accuracy 0.9771151178918169
# Precision 0.9773928909381321
# Name AB
# Accuracy 0.8640776699029126
# Precision 0.8704262504222555
# Name BC
# Accuracy 0.9715672676837726
# Precision 0.971638565126635
# Name ET
# Accuracy 0.9819694868238558
# Precision 0.9821817486483057
# Name GDB
# Accuracy 0.9382801664355063
# Precision 0.9402193898231587
# Name XGB
# Accuracy 0.9687933425797504
# Precision 0.9694426586349119
# Name STACK
# Accuracy 0.9826629680998613
# Precision 0.9827515118555562
# Name Voting
# Accuracy 0.984743411927878
# Precision 0.9848493063256964

# %%
performance_df = pd.DataFrame({
    'Algorithm' : clfs.keys(),
    'Accuracy' : accuracy_scores,
    'Precision' : precision_scores
})

# %%
performance_df.sort_values(by = 'Precision', ascending = False)
# Out:
#    Algorithm  Accuracy  Precision
# 12    Voting  0.984743   0.984849
# 11     STACK  0.982663   0.982752
# 8         ET  0.981969   0.982182
# 5         RF  0.977115   0.977393
# 0        SVC  0.976422   0.976601
# 7         BC  0.971567   0.971639
# 10       XGB  0.968793   0.969443
# 4         LR  0.968793   0.969227
# 2         NB  0.961859   0.962357
# 9        GDB  0.938280   0.940219
# 1        KNC  0.918863   0.930498
# 6         AB  0.864078   0.870426
# 3         DT  0.855756   0.863613

# %%
df.sort_values(by = 'label', ascending = True)
# Out:
#       label                                               text  num_char  \
# 4794      0  সুপারশপে গিয়েছিলাম শুভ অপরাহ্ন ক্লাসে নতুন চ্...        86
# 4793      0  তুমি কি পড়াশোনা করছো শুভ অপরাহ্ন আমার মা আজ ব...       104
# 4792      0  আজ দাদুর জন্মদিন তুমি খুব ভালো বন্ধু আজ রাতে ক...        52
# 4791      0  আশা করি শিগগির দেখা হবে কোন গান শুনছো আজ দিনটা...        80
# 4790      0  টিভি সিরিয়াল দেখছি আজ ওষুধ খেয়েছো চল হাসপাতা...        92
# ...     ...                                                ...       ...
# 4030      2  ক্রিপ্টো ইনভেস্টমেন্টে বড় লাভ সাইবার ডেটিং কর...        75
# 4029      2  হেলথ সাপ্লিমেন্ট অফার অভিনন্দন! লটারি জিতেছেন ...       113
# 1         2  ক্রিপ্টো বিনিয়োগে লাভবান হন! আজই শুরু করুন: h...        71
# 4028      2  আপনার একাউন্টে অননুমোদিত লগইন ফ্রি ডেটিং সাইটে...       131
# 4027      2  দ্রুত অর্থ আয় করুন অনলাইনে ফ্রি কলের সুযোগ আপ...        70
#
#       num_words  num_sentence  \
# 4794         11             1
# ...

# %%
import pickle 
pickle.dump(tfidf1, open('vectorizer1.pkl', 'wb'))
pickle.dump(stack_model, open('model1.pkl', 'wb'))
